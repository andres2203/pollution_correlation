# %%
import pandas as pd
import numpy as np
import matplotlib
import seaborn as sns

# %%
final_df = pd.read_pickle("./pickles/combined_dataframe.pkl")

# %%
final_df
# Out:
#             date        CO        NO_2         NOx        O_3       PM10  \
# 0     2008-01-01       NaN   51.000000   63.000000  47.000000  70.000000
# 1     2008-01-01  0.652554   67.084565  136.804130   9.280977  39.855419
# 2     2008-01-02       NaN   67.000000   85.000000  45.000000  64.000000
# 3     2008-01-02  0.531806   66.552372  126.825304   9.750819  21.005401
# 4     2008-01-03       NaN  101.000000  144.000000  37.000000  87.000000
# ...          ...       ...         ...         ...        ...        ...
# 11449 2019-10-26  0.300000   20.117647   35.058824  38.666667  13.833333
# 11450 2019-10-27  0.233333   17.000000   26.294118  46.666667  11.750000
# 11451 2019-10-28  0.333333   28.176471   56.647059  34.000000  12.083333
# 11452 2019-10-29  0.266667   30.411765   52.647059  24.444444  14.166667
# 11453 2019-10-30  0.533333   48.117647  123.176471  14.777778  16.666667
#
#             PM25       SO_2       city  year  population    month quarter  \
# ...

# %% [markdown]
# ## Evolution of ratio (length of public transporation/population)

# %%
# sns.lineplot(data=final_copy['population'], label="population")
fig, ax = matplotlib.pyplot.subplots()
final_df.groupby("city").plot(x="year",y="ratio",ax=ax)
# Out:
# city
# berlin       AxesSubplot(0.125,0.125;0.775x0.755)
# hong kong    AxesSubplot(0.125,0.125;0.775x0.755)
# madrid       AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %% [markdown]
# ## Correlation of pollutants and ratio (length of transportation/population)

# %%
final_df.groupby("city").plot(x="quarter",y=["CO","ratio"])
# Out:
# city
# berlin       AxesSubplot(0.125,0.125;0.775x0.755)
# hong kong    AxesSubplot(0.125,0.125;0.775x0.755)
# madrid       AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
final_df.groupby("city").plot(x="year",y="population")
# Out:
# city
# berlin       AxesSubplot(0.125,0.125;0.775x0.755)
# hong kong    AxesSubplot(0.125,0.125;0.775x0.755)
# madrid       AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
fig, ax = matplotlib.pyplot.subplots()
pop.groupby("city").plot(x="year",y="population",ax=ax)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-e86d457038a2> in <module>
#       1 fig, ax = matplotlib.pyplot.subplots()
# ----> 2 pop.groupby("city").plot(x="year",y="population",ax=ax)
#
# NameError: name 'pop' is not defined
