# %% [markdown]
# # Importing merged pollution dataframe

# %%
import pandas as pd
import numpy as np
import matplotlib

# %%
pollution_final=pd.read_pickle("./pickles/merged_pollution.pkl")

# %% [markdown]
# ### Creating new column for the year, month and quarter

# %%
pollution_final=pollution_final.assign(year=pollution_final['date'].dt.year)
pollution_final=pollution_final.assign(month=pollution_final['date'].dt.to_period('M'))
pollution_final=pollution_final.assign(quarter=pollution_final['date'].dt.to_period('Q'))

# %%
pollution_final
# Out:
#             date        CO       NO_2        NOx        O_3       PM10  \
# 0     2009-10-29  0.500000  33.812500  71.687500  16.142857  19.583333
# 1     2009-10-30  0.700000  39.312500  94.437500  15.571429  21.833333
# 2     2009-10-31  0.650000  33.312500  70.875000  18.571429  32.750000
# 3     2009-11-01  0.600000  25.000000  48.625000  18.285714  50.333333
# 4     2009-11-02  0.850000  39.312500  95.812500  13.000000  35.916667
# ...          ...       ...        ...        ...        ...        ...
# 11449 2018-04-27  0.249583  26.074783  37.939130  65.695783  26.278317
# 11450 2018-04-28  0.212917  13.512153  17.895833  71.706587  10.971154
# 11451 2018-04-29  0.218333  11.098958  14.697917  78.044643   6.955128
# 11452 2018-04-30  0.236250  20.576389  27.550347  68.814925   6.862179
# 11453 2018-05-01  0.250000  29.125000  33.750000  56.357143   4.461538
#
#             PM25      SO_2    city  year    month quarter
# ...

# %%
pollution_final=pollution_final.astype({"date":"datetime64","CO":"float","NO_2":"float","NOx":"float", "O_3":"float", "PM10":"float","PM25":"float", "SO_2":"float","city":"object","year":"int64"})

# %%
pollution_final.isna().sum()/len(pollution_final)*100
# Out:
# date        0.000000
# CO         35.061987
# NO_2        0.305570
# NOx        21.878820
# O_3         0.480182
# PM10        0.532565
# PM25       43.757639
# SO_2        0.506373
# city        0.000000
# year        0.000000
# month       0.000000
# quarter     0.000000
# dtype: float64

# %% [markdown]
# ## Plotting pollution evolution

# %% [markdown]
# ### PM10

# %%
pollution_final.groupby("city").plot(x="quarter",y="PM10")
# Out:
# city
# Hong Kong    AxesSubplot(0.125,0.125;0.775x0.755)
# berlin       AxesSubplot(0.125,0.125;0.775x0.755)
# madrid       AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %% [markdown]
# ### NO_2

# %%
pollution_final.groupby("city").plot(x="quarter",y="NO_2")
# Out:
# city
# Hong Kong    AxesSubplot(0.125,0.125;0.775x0.755)
# berlin       AxesSubplot(0.125,0.125;0.775x0.755)
# madrid       AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %% [markdown]
# ### O_3

# %%
pollution_final.groupby("city").plot(x="quarter",y="O_3")
# Out:
# city
# Hong Kong    AxesSubplot(0.125,0.125;0.775x0.755)
# berlin       AxesSubplot(0.125,0.125;0.775x0.755)
# madrid       AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %% [markdown]
# ### SO_2

# %%
pollution_final.groupby("city").plot(x="quarter",y="SO_2")
# Out:
# city
# Hong Kong    AxesSubplot(0.125,0.125;0.775x0.755)
# berlin       AxesSubplot(0.125,0.125;0.775x0.755)
# madrid       AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %% [markdown]
# ### Higher cncentration of NO2 in Hong Kong

# %%
fig, ax = matplotlib.pyplot.subplots()
pollution_final.groupby("city").plot(x="quarter",y="NO_2",ax=ax)
# Out:
# city
# Hong Kong    AxesSubplot(0.125,0.125;0.775x0.755)
# berlin       AxesSubplot(0.125,0.125;0.775x0.755)
# madrid       AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object
