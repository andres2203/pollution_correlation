# %%
https://es.wikipedia.org/w/api.php
https://de.wikipedia.org/w/api.php

# %%
https://en.wikipedia.org/w/api.php?action=query&list=search&srsearch=Nelson%20Mandela&utf8=&format=json

# %%
import pandas as pd
import requests
import json

# %%
params={"srinterwiki":True}
url="https://de.wikipedia.org/w/api.php?action=query&list=search&srsearch=U-Bahn_Berlin&utf8=&format=json"
response=requests.get(url,params=params)
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'batchcomplete': '',
#  'continue': {'sroffset': 10, 'continue': '-||'},
#  'warnings': {'query': {'*': 'Unrecognized value for parameter "prop": wikitext.'}},
#  'query': {'searchinfo': {'totalhits': 6302,
#    'suggestion': 'u bahn berlin',
#    'suggestionsnippet': 'u <em>bahn berlin</em>'},
#   'search': [{'ns': 0,
#     'title': 'U-Bahn Berlin',
#     'pageid': 161699,
#     'size': 148184,
#     'wordcount': 13652,
#     'snippet': 'Die <span class="searchmatch">Berliner</span> <span class="searchmatch">U</span>-<span class="searchmatch">Bahn</span> bildet zusammen mit der S-<span class="searchmatch">Bahn</span> und den Metro-Linien bei Straßenbahn und Bus das Rückgrat des öffentlichen Personennahverkehrs von Berlin',
#     'timestamp': '2019-09-25T11:51:11Z'},
#    {'ns': 0,
#     'title': 'U-Bahn München',
#     'pageid': 183504,
#     'size': 154149,
#     'wordcount': 16206,
# ...

# %%
S = requests.Session()

URL = "https://de.wikipedia.org/w/api.php?action=query&prop=extracts&titles=U-Bahn_Berlin&format=json&formatversion=2"

R = S.get(url=URL)
DATA = R.json()

print(DATA)
R.content
# Out:
# {'batchcomplete': True, 'warnings': {'extracts': {'warnings': '"exlimit" was too large for a whole article extracts request, lowered to 1.\nHTML may be malformed and/or unbalanced and may omit inline images. Use at your own risk. Known problems are listed at https://www.mediawiki.org/wiki/Extension:TextExtracts#Caveats.'}}, 'query': {'normalized': [{'fromencoded': False, 'from': 'U-Bahn_Berlin', 'to': 'U-Bahn Berlin'}], 'pages': [{'pageid': 161699, 'ns': 0, 'title': 'U-Bahn Berlin', 'extract': '<p>Die <b>Berliner U-Bahn</b> bildet zusammen mit der S-Bahn und den Metro-Linien bei Straßenbahn und Bus das Rückgrat des öffentlichen Personennahverkehrs von Berlin. Die U-Bahn wurde 1902 als „Hoch- und Untergrundbahn“ eröffnet und besitzt heute 173\xa0Bahnhöfe, drei weitere Bahnhöfe sind im Bau. Die Berliner Verkehrsbetriebe (BVG), eine Anstalt des öffentlichen Rechts, betreiben zehn U-Bahn-Linien von insgesamt 146,6\xa0Kilometern Länge in ihrem Klein- und Großprofil. Dabei kommen 1272 Fahr
# ...
